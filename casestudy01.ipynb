# %%
import pandas as pd
data=pd.read_csv("D:/DSA/Sales_add.csv")

# %%
data
# Out:
#        Month      Region      Manager  Sales_before_digital_add(in $)  \
# 0    Month-1  Region - A  Manager - A                          132921
# 1    Month-2  Region - A  Manager - C                          149559
# 2    Month-3  Region - B  Manager - A                          146278
# 3    Month-4  Region - B  Manager - B                          152167
# 4    Month-5  Region - C  Manager - B                          159525
# 5    Month-6  Region - A  Manager - B                          137163
# 6    Month-7  Region - C  Manager - C                          130625
# 7    Month-8  Region - A  Manager - A                          131140
# 8    Month-9  Region - B  Manager - C                          171259
# 9   Month-10  Region - C  Manager - B                          141956
# 10  Month-11  Region - B  Manager - C                          159339
# 11  Month-12  Region - A  Manager - A                          178939
# ...

# %%
data[["Sales_before_digital_add(in $)","Sales_After_digital_add(in $)"]].corr()
# Out:
#                                 Sales_before_digital_add(in $)  \
# Sales_before_digital_add(in $)                        1.000000
# Sales_After_digital_add(in $)                        -0.178668
#
#                                 Sales_After_digital_add(in $)
# Sales_before_digital_add(in $)                      -0.178668
# Sales_After_digital_add(in $)                        1.000000

# %%
data.skew()
# Out:
# Sales_before_digital_add(in $)    0.578033
# Sales_After_digital_add(in $)    -0.022669
# dtype: float64

# %%
data.plot.scatter(x = 'Sales_before_digital_add(in $)', y = 'Sales_After_digital_add(in $)');

# %%
data.groupby("Region")["Manager"].unique()
# Out:
# Region
# Region - A    [Manager - A, Manager - C, Manager - B]
# Region - B    [Manager - A, Manager - B, Manager - C]
# Region - C    [Manager - B, Manager - C, Manager - A]
# Name: Manager, dtype: object

# %% [markdown]
# Each region has manager A, B and C
